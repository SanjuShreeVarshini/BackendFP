# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjuShreeVarshini/BackendFP/blob/master/DATA_VISUALIZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Upload CSV
from google.colab import files
files.upload()

# STEP 2: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style
sns.set(style="whitegrid")

# STEP 3: Load data
df = pd.read_csv("student_scores.csv")
display(df)

# ---------------- BAR CHART ----------------
# Math Marks per Student
plt.figure()
plt.bar(df["Name"], df["Math"], color="skyblue", edgecolor="black")
plt.xticks(rotation=45)
plt.xlabel("Student Name")
plt.ylabel("Math Marks")
plt.title("Math Scores of Students")
plt.show()

# ---------------- LINE CHART ----------------
# Hours Studied vs Math
plt.figure()
plt.plot(df["Hours_Studied"], df["Math"],
         color="red", marker="o", linewidth=2)
plt.xlabel("Hours Studied")
plt.ylabel("Math Marks")
plt.title("Hours Studied vs Math Marks")
plt.show()

# ---------------- SCATTER CHART ----------------
# Science vs English
plt.figure()
plt.scatter(df["Science"], df["English"],
            color="green", s=80)
plt.xlabel("Science Marks")
plt.ylabel("English Marks")
plt.title("Science vs English Marks")
plt.show()

# ---------------- HISTOGRAM ----------------
# English Marks Distribution
plt.figure()
plt.hist(df["English"], bins=5,
         color="orange", edgecolor="black")
plt.xlabel("English Marks")
plt.ylabel("Number of Students")
plt.title("English Marks Distribution")
plt.show()

# ---------------- BOX PLOT ----------------
plt.figure()
sns.boxplot(
    data=df[["Math", "Science", "English"]],
    palette="Set2"
)
plt.title("Box Plot of Subject Scores")
plt.show()

# ---------------- VIOLIN PLOT ----------------
plt.figure()
sns.violinplot(
    data=df[["Math", "Science", "English"]],
    palette="Pastel1"
)
plt.title("Violin Plot of Subject Scores")
plt.show()

# ---------------- KDE PLOT ----------------
plt.figure()
sns.kdeplot(df["Math"], fill=True, color="purple")
plt.title("KDE Plot of Math Marks")
plt.show()

# ---------------- COUNT PLOT ----------------
plt.figure()
sns.countplot(x="Hours_Studied", data=df, palette="viridis")
plt.title("Frequency of Study Hours")
plt.show()

# ---------------- AVERAGE MARKS ----------------
avg_marks = df[["Math", "Science", "English"]].mean()

plt.figure()
avg_marks.plot(kind="bar", color=["blue", "green", "red"])
plt.ylabel("Average Marks")
plt.title("Average Marks per Subject")
plt.show()

# ---------------- HEATMAP ----------------
plt.figure()
sns.heatmap(
    df.select_dtypes(include="number").corr(),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.show()
# Out:
#      <input type="file" id="files-299f9847-4628-4eed-aa1c-04e1647e90b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-299f9847-4628-4eed-aa1c-04e1647e90b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
